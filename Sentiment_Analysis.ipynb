# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.yelp.com/biz/foggy-notion-san-francisco?osq=Shopping"

# %%
req = requests.get(url)
print(req.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
divs = soup.find_all('li', attrs={'class': 'y-css-1jp2syp'}, recursive=True)

# %%
reviews = []
for div in divs:
  review = div.find('p', recurive = False)
  if review:
    reviews.append(review.text)
    print(review.text)
# Out:
# When visiting San Francisco, I was on the hunt for some novelty and gift shops.Foggy Notion was a long strip of a couple different little shops, they had a bunch of home good focused items, including candles and soaps.They didn't have much of what I was looking for exactly but still had a good selection of stuff.
# This store smells amazing. I love the smell and the aesthetics of this place. They sell candles, lotions, sage, brushes, clothing, candles, incense, etc. I brought a candle wick scissor here a while back and uses it all the time. Recently brought some gifts and an opinel for picnic use. Small store with lots of good vibes. #women-ownedbusiness
# I just purchased some candles ( made in Hudson New York) for a special  Rosh HashanaDinner....Wonderful! Get some if they're still in stock. There are also a zillion cool gifts to buy as well.Jesse
# International Women's Day was a perfect day to support women owned businesses, especially when women of race, religion, color, LGBTQ, and disability, had done so much good for the rest of our communities.  If there was one place that still opened during that day, it's Foggy Notion!  When I spent so much time browsing every last handcrafted item, it made me remind myself that this is Renegade Craft Fair all over again.  Candles, incense, socks, you name it!  They're both sustainable and handmade by women with love.  Never argue with successful efforts of working women.  Their handcrafted items would surely benefit the buyer, despite how expensive they were.  In my part, I only buy a few items, starting with a large pair of men's tie dye socks and a cylinder tin can of Chico Chai loose tea leaves.  My first few purchases must be enough to keep this women owned business running.It's been a while since I made it to Inner Richmond before heading further towards home.  The first pandemic had all of us sheltered in place.  This time, we're all at ease, but we still wear face masks.  I might be back to buy a particular item for my friend's bday or a holiday season.
# Another amazing visit to Foggy Notion.  Super helpful when i asked about the dry brushing.  Super excited to find a comb non toxic.  Am practicing to not waste paper...  That is what i love while visiting San Francisco.Thank you!
# Love Foggy Notion!  It is my go to for gifts for my best friends birthdays!  All the wonderful amazing candles, body products, bath salts... a perfect place to put together an amazing gift bag.  I've ordered online too for times I can't make it over in person.  Package arrived on time and beautifully arranged!
# Came in to find one crystal because I was astonished by the reviews to this place, and walked out with 6! Considering this is one of the biggest crystal shops in the bay area, I'm really impressed. From crystals, to incense, to clothing, and more! The workers were so welcoming, and the cashier (forgot her name) threw in some freebies and a big discount for my crystals! Definitely will come back and bring my friends who share the same passion
# This is a fantastic store.  We enjoy visiting on every excursion over to Clement St.
# Foggy Notion is such a cute and unique store. I love how they sell low waste and earth conscious items. I absolutely love the Meow Meow Tweet lip balm, it definitely does the trick for chapped lips. You could also find low waste bathroom supplies like bamboo toothbrushes, bar soaps, plastic free lotion and sun lotion. Foggy notion also sells clothing that's second hand. I definitely recommend checking out foggy notion!
# Nice little shop for gifts. Lots of good smelling things and natural, refillable potions/lotions for skin. I bought a natural bug spray, lavender linen spray, and some lip balm for gifts.

# 0  When visiting San Francisco, I was on the hunt...
# 1  This store smells amazing. I love the smell an...
# 2  I just purchased some candles ( made in Hudson...
# 3  International Women's Day was a perfect day to...
# 4  Another amazing visit to Foggy Notion.  Super ...

# %%
df['lower'] = df['reviews'].apply(lambda x: " ".join(word.lower() for word in x.split()))
df.head(3)
# Out:
#                                              reviews  \
# 0  When visiting San Francisco, I was on the hunt...
# 1  This store smells amazing. I love the smell an...
# 2  I just purchased some candles ( made in Hudson...
#
#                                                lower
# 0  when visiting san francisco, i was on the hunt...
# 1  this store smells amazing. i love the smell an...
# 2  i just purchased some candles ( made in hudson...

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
stop = stopwords.words('english')
df['no_stop'] = df['lower'].apply(lambda x: " ".join(word for word in x.split() if word not in (stop)))
df.head(3)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                              reviews  \
# 0  When visiting San Francisco, I was on the hunt...
# 1  This store smells amazing. I love the smell an...
# 2  I just purchased some candles ( made in Hudson...
#
#                                                lower  \
# 0  when visiting san francisco, i was on the hunt...
# 1  this store smells amazing. i love the smell an...
# 2  i just purchased some candles ( made in hudson...
#
#                                              no_stop
# 0  visiting san francisco, hunt novelty gift shop...
# 1  store smells amazing. love smell aesthetics pl...
# 2  purchased candles ( made hudson new york) spec...

# %%
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
df['no_punct'] = df['no_stop'].apply(lambda x: "".join(char for char in x if char not in punc))
df.head(3)
# Out:
#                                              reviews  \
# 0  When visiting San Francisco, I was on the hunt...
# 1  This store smells amazing. I love the smell an...
# 2  I just purchased some candles ( made in Hudson...
#
#                                                lower  \
# 0  when visiting san francisco, i was on the hunt...
# 1  this store smells amazing. i love the smell an...
# 2  i just purchased some candles ( made in hudson...
#
#                                              no_stop  \
# 0  visiting san francisco, hunt novelty gift shop...
# 1  store smells amazing. love smell aesthetics pl...
# 2  purchased candles ( made hudson new york) spec...
#
#                                             no_punct
# 0  visiting san francisco hunt novelty gift shops...
# 1  store smells amazing love smell aesthetics pla...
# 2  purchased candles  made hudson new york specia...

# %%
import textblob
from textblob import Word, TextBlob

# %%
df['clean_reviews'] = df['no_punct'].apply(lambda x: " ".join(lemmatizer.lemmatize(word) for word in x.split()))

# %%
df.head(3)
# Out:
#                                              reviews  \
# 0  When visiting San Francisco, I was on the hunt...
# 1  This store smells amazing. I love the smell an...
# 2  I just purchased some candles ( made in Hudson...
#
#                                                lower  \
# 0  when visiting san francisco, i was on the hunt...
# 1  this store smells amazing. i love the smell an...
# 2  i just purchased some candles ( made in hudson...
#
#                                              no_stop  \
# 0  visiting san francisco, hunt novelty gift shop...
# 1  store smells amazing. love smell aesthetics pl...
# 2  purchased candles ( made hudson new york) spec...
#
#                                             no_punct  \
# 0  visiting san francisco hunt novelty gift shops...
# 1  store smells amazing love smell aesthetics pla...
# 2  purchased candles  made hudson new york specia...
#
#                                        clean_reviews
# 0  visiting san francisco hunt novelty gift shops...
# 1  store smell amazing love smell aesthetic place...
# 2  purchased candle made hudson new york special ...

# %%
df['polarity'] = df['clean_reviews'].apply(lambda x: TextBlob(x).sentiment[0])
df['subjectivity'] = df['clean_reviews'].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df.head(8)
# Out:
#                                              reviews  \
# 0  When visiting San Francisco, I was on the hunt...
# 1  This store smells amazing. I love the smell an...
# 2  I just purchased some candles ( made in Hudson...
# 3  International Women's Day was a perfect day to...
# 4  Another amazing visit to Foggy Notion.  Super ...
# 5  Love Foggy Notion!  It is my go to for gifts f...
# 6  Came in to find one crystal because I was asto...
# 7  This is a fantastic store.  We enjoy visiting ...
#
#                                                lower  \
# 0  when visiting san francisco, i was on the hunt...
# 1  this store smells amazing. i love the smell an...
# 2  i just purchased some candles ( made in hudson...
# 3  international women's day was a perfect day to...
# 4  another amazing visit to foggy notion. super h...
# 5  love foggy notion! it is my go to for gifts fo...
# 6  came in to find one crystal because i was asto...
# 7  this is a fantastic store. we enjoy visiting o...
#
#                                              no_stop  \
# 0  visiting san francisco, hunt novelty gift shop...
# 1  store smells amazing. love smell aesthetics pl...
# 2  purchased candles ( made hudson new york) spec...
# 3  international women's day perfect day support ...
# 4  another amazing visit foggy notion. super help...
# 5  love foggy notion! go gifts best friends birth...
# 6  came find one crystal astonished reviews place...
# 7  fantastic store. enjoy visiting every excursio...
#
#                                             no_punct  \
# 0  visiting san francisco hunt novelty gift shops...
# 1  store smells amazing love smell aesthetics pla...
# 2  purchased candles  made hudson new york specia...
# 3  international womens day perfect day support w...
# 4  another amazing visit foggy notion super helpf...
# 5  love foggy notion go gifts best friends birthd...
# 6  came find one crystal astonished reviews place...
# 7  fantastic store enjoy visiting every excursion...
#
#                                        clean_reviews  polarity  subjectivity
# 0  visiting san francisco hunt novelty gift shops...  0.230357      0.450000
# 1  store smell amazing love smell aesthetic place...  0.258333      0.458333
# 2  purchased candle made hudson new york special ...  0.281169      0.558658
# 3  international woman day perfect day support wo...  0.216859      0.450954
# 4  another amazing visit foggy notion super helpf...  0.267857      0.597619
# 5  love foggy notion go gift best friend birthday...  0.792857      0.814286
# 6  came find one crystal astonished review place ...  0.300000      0.420000
# 7  fantastic store enjoy visiting every excursion...  0.400000      0.700000

# %%
import google.generativeai as genai

# %%
pol, sub = df['polarity'].mean(), df['subjectivity'].mean()

# %%
pol, sub
# Out:
# (0.316185520828378, 0.5499080416937561)

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
api_key = 'AIzaSyCNfiNk7h_UJPSa248MB5WIPiJlzThptSE'
genai.configure(api_key=api_key)

# %%
response = model.generate_content(f'Write a short feedback for a product (around 25-30 words) that has following sentiment metrics: polarity={pol} , subjectivity= {sub}')

print(response.text)
# Out:
# It's a decent product with some potential, but could use some improvements.
